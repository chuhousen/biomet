# %% [markdown]
# ## Using 2013 Westpond data to predict 2014/2015
#
# ### Train Features
# 1. land surface temp (wp_LST.day)
# 2. sensible heat flux (wp_le)
# 3. latent heat flux (wp_h)
# 4. net radiation (net_rad)
# 5. avg air temp (avg_air_temp)

# %%
# %matplotlib inline
import sys
sys.path.append('../')
import exp
import regression as r
import numpy as np

# %%
df = exp.get_exp1_data()
df.head()
# Out:
#    avg_air_temp  avg_soil_temp  doy  net_rad  year    wp_ch4_gf   wp_co2_gf  \
# 0          19.2           22.3  195    190.0  2012  4332.368657 -304.542172
# 1          19.3           21.8  196    189.0  2012  5305.896768 -335.648791
# 2          20.3           21.9  197    187.0  2012  6215.371936 -313.150966
# 3          16.8           22.4  198    186.0  2012  7129.353337 -339.900067
# 4          17.0           21.5  199    151.0  2012  7070.768573 -319.771564
#
#         wp_er      wp_gpp         wp_h      ...        mb_bnd2   mb_bnd3  \
# 0  145.072376 -449.614548  1447.549899      ...       0.187575  0.025212
# 1  150.278671 -485.927462  1921.833137      ...       0.186562  0.024569
# 2  158.307017 -471.457982  1176.374322      ...       0.185550  0.023925
# 3  153.561669 -493.461736  2575.636175      ...       0.184537  0.023281
# 4  144.053480 -463.825044  1916.081260      ...       0.183525  0.022638
#
#     mb_bnd7    mb_evi   mb_lswi  mb_ndvi  wp_LST.day  wp_LST.night  \
# 0  0.053137  0.298162  0.562370   0.6491       29.61       17.2850
# 1  0.051306  0.296544  0.574074   0.6504       29.63       17.2325
# 2  0.049475  0.294925  0.585779   0.6517       29.65       17.1800
# 3  0.047644  0.293306  0.597483   0.6530       29.67       17.1275
# 4  0.045812  0.291687  0.609188   0.6543       29.69       17.0750
#
#    mb_LST.day  mb_LST.night
# 0     26.3350       18.6450
# 1     26.4075       18.5925
# 2     26.4800       18.5400
# 3     26.5525       18.4875
# 4     26.6250       18.4350
#
# [5 rows x 35 columns]

# %%
X_cols, Y_cols = ["wp_LST.day", "wp_h", "wp_le", "net_rad", "avg_air_temp"], ["wp_er"]
train_years, test_years = [2013], [2014, 2015]
X_train, Y_train = exp.featurize(df, X_cols, Y_cols, years=train_years)
X_test, Y_test = exp.featurize(df, X_cols, Y_cols, years=test_years)

# %%
Y_pred = r.predict(r.random_forests(), X_train, Y_train, X_test, Y_test)
r.visualize_preds(df, Y_test, Y_pred, test_years=test_years)
# Out:
# R2-score:  0.760096662963

# %%
Y_pred = r.predict(r.xgb_trees(), X_train, Y_train, X_test, Y_test)
r.visualize_preds(df, Y_test, Y_pred, test_years=test_years)
# Out:
# R2-score:  0.742391898079

# %%
Y_pred = r.predict(r.svm(), X_train, Y_train, X_test, Y_test)
r.visualize_preds(df, Y_test, Y_pred, test_years=test_years)
# Out:
# R2-score:  0.780481660538

# %%
Y_pred = r.predict(r.dnn(), X_train, Y_train, X_test, Y_test)
r.visualize_preds(df, Y_test, Y_pred, test_years=test_years)
# Out:
# Step #1, avg. loss: 15241.01758
# Step #501, epoch #125, avg. loss: 1212.09363
# Step #1001, epoch #250, avg. loss: 277.80695
# Step #1501, epoch #375, avg. loss: 206.90450
# Step #2001, epoch #500, avg. loss: 164.45674
# Step #2501, epoch #625, avg. loss: 127.60720
# Step #3001, epoch #750, avg. loss: 97.34262
# Step #3501, epoch #875, avg. loss: 73.07131
# Step #4001, epoch #1000, avg. loss: 58.09585
# Step #4501, epoch #1125, avg. loss: 48.59120
# R2-score:  0.538743109535
